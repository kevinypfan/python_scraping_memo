# %%
import requests
from bs4 import BeautifulSoup
import re
pages = set()
titles = []
dict_vedio = []

# %%
response = requests.get('https://www.youtube.com/results?search_query=violeta')

# %%
html = response.text

# %%
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html data-cast-api-enabled="true" lang="zh-TW">
#  <head>
#   <style name="www-roboto">
#    @font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}
#   </style>
#   <script name="www-roboto">
# ...

# %%
list_int = ['1','2','3']
dir(list_int)
int(''.join(list_int))
# Out:
# 123

# %%
all_video_tag = bs.find_all('div', {'class': 'yt-lockup-dismissable'})
# video_views_list = re.findall('\d+', all_video_tag[5].find('span', {'class': 'view-count'}).text)
# video_views_int = ''.join(video_views_list)
# video_views_int
# dir(all_video_tag[5])
# print(all_video_tag[4].span)
print(all_video_tag[0].find('a', { 'class': 'yt-uix-tile-link' }).attrs['title'])
# Out:
# IZ*ONE (아이즈원) - 비올레타 (Violeta) MV

# %%
print(all_video_tag[0].find('a', { 'class': 'yt-uix-tile-link' }).attrs['href'].split('=')[-1])
# Out:
# 6eEZ7DJMzuk

# %%
all_video_tag[0].find('span', { 'class': 'video-time' }).string
# Out:
# '3:25'

# %%
print(all_video_tag[1].prettify())
# Out:
# <div class="yt-lockup-dismissable yt-uix-tile">
#  <div class="yt-lockup-thumbnail contains-addto">
#   <a aria-hidden="true" class="yt-uix-sessionlink spf-link" data-sessionlink="itct=CE0Q3DAYASITCKrJxcKW0OICFZZmYAod3MYNDSj0JDIGc2VhcmNoUgd2aW9sZXRh" href="/watch?v=kMvawxzCClk">
#    <div class="yt-thumb video-thumb">
#     <span class="yt-thumb-simple">
#      <img alt="" data-ytimg="1" height="138" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="https://i.ytimg.com/vi/kMvawxzCClk/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&amp;rs=AOn4CLA5ClewSjCGqcjxqp5n2FNMxGt1aA" width="246"/>
#      <span aria-hidden="true" class="video-time">
#       3:19
#      </span>
#     </span>
#    </div>
#   </a>
#   <span class="thumb-menu dark-overflow-action-menu video-actions">
# ...

# %%
# print(all_video_tag[].parent.contents[-1].string)

# %%
print(all_video_tag[4].find('span', {'class': 'video-time'}).string)
# Out:
# 3:26

# %%
# print(all_video_tag[5].prettify())

# %%
type(all_video_tag[3].find('a', { 'class': 'yt-uix-tile-link' }))
# Out:
# bs4.element.Tag

# %%
# re.search('^\\n\s*(.*)\\n\s+', all_video_tag[5].span.text).group(1)

# %%
# re.search('([\d,]+)次$', all_video_tag[5].span.attrs['aria-label']).group(1)

# %%
# all_video_tag[5].attrs['href'].split('=')[-1]

# %%
for link in all_video_tag:
    if link.find('a', { 'class': 'yt-uix-tile-link' }).attrs['href'] not in pages:
        try:
            print(link.find('span', {'class': 'video-time'}).string)
            pages.add(link.find('a', { 'class': 'yt-uix-tile-link' }).attrs['title'])
            dict_data = {
                'title':link.find('a', { 'class': 'yt-uix-tile-link' }).attrs['title'], 
                'link_id':link.find('a', { 'class': 'yt-uix-tile-link' }).attrs['href'].split('=')[-1], 
                'time': link.find('span', {'class': 'video-time'}).string, 
                'views': int(''.join(re.search('([\d,]+)次$', link.find('a', { 'class': 'yt-uix-tile-link' }).span.attrs['aria-label']).group(1).split(','))) 
            }
            print(dict_data)
            titles.append(dict_data)
        except:
            print('something error!')
            # Key is not present
            pass
# Out:
# 3:25
# {'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) MV', 'link_id': '6eEZ7DJMzuk', 'time': '3:25', 'views': 34863188}
# 3:19
# {'title': '[IZ*ONE - Violeta] dance practice mirrored', 'link_id': 'kMvawxzCClk', 'time': '3:19', 'views': 279319}
# 3:31
# {'title': '[IZ*ONE - VIOLETA] MCD PREMIERE SHOWCASE Stage | M COUNTDOWN 190404 EP.613', 'link_id': 'SFYUrWkNLjw', 'time': '3:31', 'views': 2199705}
# 3:38
# {'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) Dance Practice', 'link_id': 'Z8_aiEDLoY4', 'time': '3:38', 'views': 5430121}
# 3:26
# {'title': '[IZ*ONE - Violeta] KPOP TV Show |   M COUNTDOWN 190411 EP.614', 'link_id': '0ncVyYpsPHk', 'time': '3:26', 'views': 1707974}
# 3:26
# {'title': '[IZ*ONE - Violeta] KPOP TV Show | M COUNTDOWN 190418 EP.615', 'link_id': 'xQcjn0nvJgs', 'time': '3:26', 'views': 1350103}
# 3:27
# {'title': '[최초공개] 아이즈원(IZ*ONE) - 비올레타 (Violeta)｜IZ*ONE COMEBACK SHOW', 'link_id': 'SDGWotu_pDY', 'time': '3:27', 'views': 5272809}
# 3:20
# ...

# %%
# temp_data = []

# for index in range(len(dict_vedio)):
#     try:
#         temp_data.append(dict_vedio[index].attrs['aria-label'])
#     except:
#         pass

# %%
# temp_data[0]

# %%
pages
# Out:
# {"BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) feat. Halsey' Official MV",
#  'IZ*ONE (아이즈원) - Violeta (비올레타) (Color Coded Lyrics Eng/Rom/Han/가사)',
#  'IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV',
#  'IZ*ONE (아이즈원) - 비올레타 (Violeta) - Lisa Rhee Dance Tutorial',
#  'IZ*ONE (아이즈원) - 비올레타 (Violeta) Dance Practice',
#  'IZ*ONE (아이즈원) - 비올레타 (Violeta) MV',
#  'IZ*ONE(아이즈원) - Violeta(비올레타) @SUPER CONCERT 20190505',
#  'IZ*ONE(아이즈원) - Violeta(비올레타) @인기가요 Inkigayo 20190421',
#  'TWICE "FANCY" M/V',
#  '[HOT] IZ*ONE  - Violeta ,  아이즈원 - 비올레타 Show Music   core 20190413',
#  '[IZ*ONE - VIOLETA] MCD PREMIERE SHOWCASE Stage | M COUNTDOWN 190404 EP.613',
#  '[IZ*ONE - Violeta] KPOP TV Show |   M COUNTDOWN 190411 EP.614',
#  '[IZ*ONE - Violeta] KPOP TV Show | M COUNTDOWN 190418 EP.615',
#  '[IZ*ONE - Violeta] dance practice mirrored',
#  '[SPECIAL VIDEO] IZ*ONE (아이즈원) - 비올레타 (Violeta) Dance Practice Close up Ver.',
#  '[최초공개] 아이즈원(IZ*ONE) - 비올레타 (Violeta)｜IZ*ONE COMEBACK SHOW',
# ...

# %%
titles
# Out:
# [{'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) MV',
#   'link_id': '6eEZ7DJMzuk',
#   'time': '3:25',
#   'views': 34863188},
#  {'title': '[IZ*ONE - Violeta] dance practice mirrored',
#   'link_id': 'kMvawxzCClk',
#   'time': '3:19',
#   'views': 279319},
#  {'title': '[IZ*ONE - VIOLETA] MCD PREMIERE SHOWCASE Stage | M COUNTDOWN 190404 EP.613',
#   'link_id': 'SFYUrWkNLjw',
#   'time': '3:31',
#   'views': 2199705},
#  {'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) Dance Practice',
#   'link_id': 'Z8_aiEDLoY4',
#   'time': '3:38',
#   'views': 5430121},
#  {'title': '[IZ*ONE - Violeta] KPOP TV Show |   M COUNTDOWN 190411 EP.614',
#   'link_id': '0ncVyYpsPHk',
#   'time': '3:26',
#   'views': 1707974},
#  {'title': '[IZ*ONE - Violeta] KPOP TV Show | M COUNTDOWN 190418 EP.615',
#   'link_id': 'xQcjn0nvJgs',
#   'time': '3:26',
#   'views': 1350103},
#  {'title': '[최초공개] 아이즈원(IZ*ONE) - 비올레타 (Violeta)｜IZ*ONE COMEBACK SHOW',
#   'link_id': 'SDGWotu_pDY',
#   'time': '3:27',
# ...

# %%
temp_list = []
for el in titles:
    temp_list.append(el['views'])
temp_list
# Out:
# [34863188,
#  279319,
#  2199705,
#  5430121,
#  1707974,
#  1350103,
#  5272809,
#  264120,
#  342856,
#  697770,
#  4010938,
#  619529,
#  92241623,
#  348319346,
#  115953642,
#  2218678,
#  140790,
#  288,
#  1219770]

# %%
newlist = sorted(titles, key=lambda k: k['views'], reverse=True)

# %%
newlist[0:3]
# Out:
# [{'title': "BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) feat. Halsey' Official MV",
#   'link_id': 'XsX3ATc3FbA',
#   'time': '4:13',
#   'views': 348319346},
#  {'title': 'TWICE "FANCY" M/V',
#   'link_id': 'kOHB85vDuow',
#   'time': '3:39',
#   'views': 115953642},
#  {'title': 'IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV',
#   'link_id': 'WZwr2a_lFWY',
#   'time': '3:40',
#   'views': 92241623}]

# %%
[
{'title': 'TWICE "FANCY" M/V', 'link_id': 'kOHB85vDuow', 'views': 114750882},
{'title': '[KCON 2019 JAPAN] TWICE - INTRO + FANCYㅣKCON 2019 JAPAN × M COUNTDOWN', 'link_id': 'odU4qAyKKbs', 'views': 1490567},
{'title': '[KCON 2019 JAPAN] TWICE - BDZㅣKCON 2019 JAPAN × M COUNTDOWN', 'link_id': '400Ki4hG6kw', 'views': 1043873},
{'title': 'TWICE "What is Love?" M/V', 'link_id': 'i0p1bmr0EmE', 'views': 298628726},
{'title': 'ITZY (있지) - 달라달라 (DALLA DALLA) 무대교차편집', 'link_id': 'MxvWsfZGWfQ', 'views': 4735469},
{'title': 'BTS - Dionysus (방탄소년단 - Dionysus) [Color Coded Lyrics/Han/Rom/Eng/가사]', 'link_id': 'YmimK6HxqK4', 'views': 12621955},
{'title': "EXID(이엑스아이디) - 'ME&YOU' Music Video", 'link_id': 'g9wfhJRyur8', 'views': 9218841},
{'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) MV', 'link_id': '6eEZ7DJMzuk', 'views': 34663154},
{'title': '[MV] (G)I-DLE((여자)아이들) _ Senorita', 'link_id': 'G8APgeFfkAk', 'views': 25599799},
{'title': "Red Velvet 레드벨벳 'Bad Boy' MV", 'link_id': 'J_CFBjAyPWE', 'views': 210702226},
{'title': 'TWICE(트와이스)-FANCY[Music Bank/2019.05.03]', 'link_id': 'JcTS-g3VJA4', 'views': 1648918},
{'title': "BLACKPINK - '마지막처럼 (AS IF IT'S YOUR LAST)' M/V", 'link_id': 'Amq-qlqbjYA', 'views': 606710681},
{'title': '[Full Album] TWICE(트와이스) - FANCY YOU', 'link_id': 'bTBxbfev9lU', 'views': 215441},
{'title': 'TWICE "Dance The Night Away" M/V', 'link_id': 'Fm5iP0S1z9w', 'views': 174949914},
{'title': 'EXO 엑소 "Love Shot" MV', 'link_id': 'pSudEWBAYRE', 'views': 149437619},
{'title': 'TWICE "YES or YES" M/V', 'link_id': 'mAKsZ26SabQ', 'views': 181118306},
{'title': 'TWICE "LIKEY" M/V', 'link_id': 'V2hlQkVJZhE', 'views': 382466962},
{'title': 'ITZY "달라달라(DALLA DALLA)" M/V', 'link_id': 'pNfTK39k55U', 'views': 122823322},
{'title': 'TWICE "CHEER UP" M/V', 'link_id': 'c7rCyll5AeY', 'views': 337613818},
{'title': 'IZ*ONE (아이즈원) - Violeta (비올레타) (Color Coded Lyrics Eng/Rom/Han/가사)', 'link_id': '6di5tkf5oYw', 'views': 3971962},
{'title': "Red Velvet 레드벨벳 'Power Up' MV", 'link_id': 'aiHSVQy9xN8', 'views': 82026199},
{'title': 'Stray Kids "MIROH" M/V', 'link_id': 'Dab4EENTW5I', 'views': 43391719},
{'title': 'TWICE (트와이스) "ONE IN A MILLION" Japan Showcase [ENG/日本語/中文 TRANSLATION]', 'link_id': 'Cr3_QLfLJTE', 'views': 2040139},
{'title': "EXO 엑소 'Ko Ko Bop' MV", 'link_id': 'IdssuxDdqKk', 'views': 221543006},
{'title': 'BTS - Make It Right (방탄소년단 - Make It Right) [Color Coded Lyrics/Han/Rom/Eng/가사]', 'link_id': 'F2mbAkat5n8', 'views': 17018155},
{'title': 'TWICE "Heart Shaker" M/V', 'link_id': 'rRzxEiBLQCA', 'views': 269668666},
{'title': "BLACKPINK - 'Kill This Love' DANCE PRACTICE VIDEO (MOVING VER.)", 'link_id': 'MOwaUlXZxkI', 'views': 99177211},
{'title': 'TWICE "Like OOH-AHH(OOH-AHH하게)" M/V', 'link_id': '0rtV5esQT6I', 'views': 305125276},
{'title': "BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) feat. Halsey' Official MV", 'link_id': 'XsX3ATc3FbA', 'views': 344540045},
{'title': 'GOT7 "ECLIPSE" M/V', 'link_id': '6tl-MG38-0E', 'views': 33972570},
{'title': "NCT 127 엔시티 127 'Superhuman' MV", 'link_id': 'x95oZNxW5Rc', 'views': 9136911},
{'title': "BLACKPINK - 'Don't Know What To Do' DANCE PRACTICE VIDEO (MOVING VER.)", 'link_id': 'bqzDuRz_P7g', 'views': 48438365},
{'title': 'TWICE(트와이스)- FANCY [Music Bank COME BACK/2019.04.26]', 'link_id': '547LCSYK8Xg', 'views': 1847982}
]
# Out:
# [{'title': 'TWICE "FANCY" M/V', 'link_id': 'kOHB85vDuow', 'views': 114750882},
#  {'title': '[KCON 2019 JAPAN] TWICE - INTRO + FANCYㅣKCON 2019 JAPAN × M COUNTDOWN',
#   'link_id': 'odU4qAyKKbs',
#   'views': 1490567},
#  {'title': '[KCON 2019 JAPAN] TWICE - BDZㅣKCON 2019 JAPAN × M COUNTDOWN',
#   'link_id': '400Ki4hG6kw',
#   'views': 1043873},
#  {'title': 'TWICE "What is Love?" M/V',
#   'link_id': 'i0p1bmr0EmE',
#   'views': 298628726},
#  {'title': 'ITZY (있지) - 달라달라 (DALLA DALLA) 무대교차편집',
#   'link_id': 'MxvWsfZGWfQ',
#   'views': 4735469},
#  {'title': 'BTS - Dionysus (방탄소년단 - Dionysus) [Color Coded Lyrics/Han/Rom/Eng/가사]',
#   'link_id': 'YmimK6HxqK4',
#   'views': 12621955},
#  {'title': "EXID(이엑스아이디) - 'ME&YOU' Music Video",
#   'link_id': 'g9wfhJRyur8',
#   'views': 9218841},
#  {'title': 'IZ*ONE (아이즈원) - 비올레타 (Violeta) MV',
#   'link_id': '6eEZ7DJMzuk',
#   'views': 34663154},
#  {'title': '[MV] (G)I-DLE((여자)아이들) _ Senorita',
#   'link_id': 'G8APgeFfkAk',
# ...
