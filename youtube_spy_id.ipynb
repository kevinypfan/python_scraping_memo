# %%
import requests
from bs4 import BeautifulSoup, element
import re
titles = []

# %%
response = requests.get('https://www.youtube.com/watch?v=6eEZ7DJMzuk')

# %%
html = response.text

# %%
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html data-cast-api-enabled="true" lang="zh-TW">
#  <head>
#   <style name="www-roboto">
#    @font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}
#   </style>
#   <script name="www-roboto">
# ...

# %%
all_video_tag = bs.find_all('li',{ 'class': 'video-list-item'})
# all_video_tag = bs.find_all('div', {'class': 'ytd-watch-next-secondary-results-renderer'})
all_video_tag
# Out:
# [<li class="video-list-item related-list-item show-video-time">
#  <div class="content-wrapper">
#  <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHYXV0b25hdkjpnbOSw73G8OkB" data-visibility-tracking="CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUDmqpT_mvuKzlk=" href="/watch?v=WZwr2a_lFWY" rel="spf-prefetch nofollow" title="IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV">
#  <span aria-describedby="description-id-166394" class="title" dir="ltr">
#      IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV
#    </span>
#  <span class="accessible-description" id="description-id-166394">
#       - 播放時間：3:40。
#    </span>
#  <span class="stat attribution"><span class="">Stone Music Entertainment</span></span>
#  <span class="stat view-count">觀看次數：92,256,155次</span>
#  </a>
#  </div>
#  <div class="thumb-wrapper">
# ...

# %%
all_video_tag[0].find('a', { 'class': 'content-link' })
# Out:
# <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHYXV0b25hdkjpnbOSw73G8OkB" data-visibility-tracking="CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUDmqpT_mvuKzlk=" href="/watch?v=WZwr2a_lFWY" rel="spf-prefetch nofollow" title="IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV">
# <span aria-describedby="description-id-166394" class="title" dir="ltr">
#     IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV
#   </span>
# <span class="accessible-description" id="description-id-166394">
#      - 播放時間：3:40。
#   </span>
# <span class="stat attribution"><span class="">Stone Music Entertainment</span></span>
# <span class="stat view-count">觀看次數：92,256,155次</span>
# </a>

# %%
all_video_tag[0].find('span', { 'class': 'video-time' }).string
# Out:
# '3:40'

# %%
all_video_tag[0]
# Out:
# <li class="video-list-item related-list-item show-video-time">
# <div class="content-wrapper">
# <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHYXV0b25hdkjpnbOSw73G8OkB" data-visibility-tracking="CCwQpDAYACITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUDmqpT_mvuKzlk=" href="/watch?v=WZwr2a_lFWY" rel="spf-prefetch nofollow" title="IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV">
# <span aria-describedby="description-id-166394" class="title" dir="ltr">
#     IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV
#   </span>
# <span class="accessible-description" id="description-id-166394">
#      - 播放時間：3:40。
#   </span>
# <span class="stat attribution"><span class="">Stone Music Entertainment</span></span>
# <span class="stat view-count">觀看次數：92,256,155次</span>
# </a>
# </div>
# <div class="thumb-wrapper">
# ...

# %%
all_video_tag[1].find('a', { 'class': 'content-link' }) if type(all_video_tag[1].find('a', { 'class': 'content-link' })) else None

# %%
type(all_video_tag[2].find('a', { 'class': 'content-link' })) == element.Tag
# Out:
# True

# %%
all_video_tag[3]
# Out:
# <li class="video-list-item related-list-item show-video-time related-list-item-compact-video">
# <div class="content-wrapper">
# <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCcQpDAYAyITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHcmVsYXRlZEjpnbOSw73G8OkB" data-visibility-tracking="CCcQpDAYAyITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUDegKmJ4e3r49kB" href="/watch?v=2cevbhEqQF4" rel="spf-prefetch nofollow" title="(여자)아이들((G)I-DLE) - 'Senorita' Official Music Video">
# <span aria-describedby="description-id-464559" class="title" dir="ltr">
#     (여자)아이들((G)I-DLE) - 'Senorita' Official Music Video
#   </span>
# <span class="accessible-description" id="description-id-464559">
#      - 播放時間：3:45。
#   </span>
# <span class="stat attribution"><span class="">(G)I-DLE (여자)아이들 (Official YouTube Channel)</span></span>
# <span class="stat view-count">觀看次數：20,430,195次</span>
# </a>
# </div>
# <div class="thumb-wrapper">
# ...

# %%
all_video_tag[4]
# Out:
# <li class="video-list-item related-list-item show-video-time related-list-item-compact-video">
# <div class="content-wrapper">
# <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCYQpDAYBCITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHcmVsYXRlZEjpnbOSw73G8OkB" data-visibility-tracking="CCYQpDAYBCITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUCS2frXi-vT3Bc=" href="/watch?v=F7lPWLr-rJI" rel="spf-prefetch nofollow" title="PRODUCE X 101 [최초공개]프로듀스 X 101 ′_지마(X1-MA)′ Performance">
# <span aria-describedby="description-id-126296" class="title" dir="ltr">
#     PRODUCE X 101 [최초공개]프로듀스 X 101 ′_지마(X1-MA)′ Performance
#   </span>
# <span class="accessible-description" id="description-id-126296">
#      - 播放時間：5:24。
#   </span>
# <span class="stat attribution"><span class="">Mnet Official</span></span>
# <span class="stat view-count">觀看次數：11,480,148次</span>
# </a>
# </div>
# <div class="thumb-wrapper">
# ...

# %%
all_video_tag[5]
# Out:
# <li class="video-list-item related-list-item show-video-time related-list-item-compact-playlist"><a class="related-playlist yt-pl-thumb-link spf-link vve-check yt-uix-sessionlink spf-link" data-sessionlink="itct=CCUQojAYBSITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHcmVsbGlzdEjpnbOSw73G8OkB" data-visibility-tracking="CCUQojAYBSITCI3qgMqb0OICFZQeYAodWJUB4Sj4HQ==" href="/watch?v=LYh3yDc4pCM&amp;list=PLBSvleni5is2u66UMpc7nLOK6hh7w5OrQ" rel="spf-prefetch"> <span class="yt-pl-thumb">
# <span class="video-thumb yt-thumb yt-thumb-168">
# <span class="yt-thumb-default">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="https://i.ytimg.com/vi/LYh3yDc4pCM/hqdefault.jpg?sqp=-oaymwEWCKgBEF5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLCHoJN_hFZ2pbndToQbZxYLfQbLqA" data-ytimg="1" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="168"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# <span class="sidebar">
# ...

# %%
all_video_tag[6]
# Out:
# <li class="video-list-item related-list-item show-video-time related-list-item-compact-video">
# <div class="content-wrapper">
# <a class="content-link spf-link yt-uix-sessionlink spf-link" data-sessionlink="itct=CCQQpDAYBiITCI3qgMqb0OICFZQeYAodWJUB4Sj4HTIHcmVsYXRlZEjpnbOSw73G8OkB" data-visibility-tracking="CCQQpDAYBiITCI3qgMqb0OICFZQeYAodWJUB4Sj4HUCJxf64kcff-0I=" href="/watch?v=Qvd-ORcfook" rel="spf-prefetch nofollow" title="아이즈원(IZ*ONE) - 비올레타(Violeta) 교차편집(stage mix)">
# <span aria-describedby="description-id-418834" class="title" dir="ltr">
#     아이즈원(IZ*ONE) - 비올레타(Violeta) 교차편집(stage mix)
#   </span>
# <span class="accessible-description" id="description-id-418834">
#      - 播放時間：3:25。
#   </span>
# <span class="stat attribution"><span class="">aid tun김교차</span></span>
# <span class="stat view-count">觀看次數：712,103次</span>
# </a>
# </div>
# <div class="thumb-wrapper">
# ...

# %%
for link in all_video_tag:
    content_link = link.find('a', { 'class': 'content-link' }) if type(link.find('a', { 'class': 'content-link' })) == element.Tag else None
    if content_link == None:
        continue
    if 'href' in content_link.attrs:
        try:
            print(content_link.attrs['href'].split('=')[-1])
            dict_data = {
                'title': content_link.attrs['title'], 
                'link_id': content_link.attrs['href'].split('=')[-1],
                'time': link.find('span', {'class': 'video-time'}).string,
                'views': int(''.join(re.search('([\d,]+)次$', link.find('span', {'class': re.compile('view-count')}).text).group(1).split(','))) 
            }
            titles.append(dict_data)
        except:
            # Key is not present
            pass
# Out:
# WZwr2a_lFWY
# kOHB85vDuow
# 2cevbhEqQF4
# F7lPWLr-rJI
# Qvd-ORcfook
# HlN2BXNJzxA
# uTcZ3IizpLE
# udGwca1HBM4
# GQqyCeKf8rw
# chPakGa0BwU
# Y4rpPrOOS_w
# RMJFEvHvmD0
# fNkxFo5Ef38
# SDGWotu_pDY
# Jk79mtC2xFY
# pNfTK39k55U
# nlxujPAwoXE
# g9wfhJRyur8

# %%
re.search('([\d,]+)次$', all_video_tag[0].find('span', {'class': re.compile('view-count')}).text).group(1)
# Out:
# '92,256,155'

# %%
titles
# Out:
# [{'title': 'IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV',
#   'link_id': 'WZwr2a_lFWY',
#   'time': '3:40',
#   'views': 92256155},
#  {'title': 'TWICE "FANCY" M/V',
#   'link_id': 'kOHB85vDuow',
#   'time': '3:39',
#   'views': 115988736},
#  {'title': "(여자)아이들((G)I-DLE) - 'Senorita' Official Music Video",
#   'link_id': '2cevbhEqQF4',
#   'time': '3:45',
#   'views': 20430195},
#  {'title': 'PRODUCE X 101 [최초공개]프로듀스 X 101 ′_지마(X1-MA)′ Performance',
#   'link_id': 'F7lPWLr-rJI',
#   'time': '5:24',
#   'views': 11480148},
#  {'title': '아이즈원(IZ*ONE) - 비올레타(Violeta) 교차편집(stage mix)',
#   'link_id': 'Qvd-ORcfook',
#   'time': '3:25',
#   'views': 712103},
#  {'title': '청하 (CHUNG HA) - "벌써 12시 (Gotta Go)" Music Video',
#   'link_id': 'HlN2BXNJzxA',
#   'time': '3:42',
#   'views': 27057777},
#  {'title': "[PRODUCE 48] Nation's Hot Issue [국.슈 (국프의 핫이슈)] - Rumor [HAN|ROM|ENG Color Coded Lyrics]",
#   'link_id': 'uTcZ3IizpLE',
#   'time': '3:17',
#   'views': 14855310},
# ...

# %%
list_dict = [{'title': 'IZ*ONE (아이즈원) - 라비앙로즈 (La Vie en Rose) MV',
  'link_id': 'WZwr2a_lFWY',
  'time': '3:40',
  'views': 92256155},
 {'title': 'TWICE "FANCY" M/V',
  'link_id': 'kOHB85vDuow',
  'time': '3:39',
  'views': 115988736},
 {'title': "(여자)아이들((G)I-DLE) - 'Senorita' Official Music Video",
  'link_id': '2cevbhEqQF4',
  'time': '3:45',
  'views': 20430195},
 {'title': 'PRODUCE X 101 [최초공개]프로듀스 X 101 ′_지마(X1-MA)′ Performance',
  'link_id': 'F7lPWLr-rJI',
  'time': '5:24',
  'views': 11480148},
 {'title': '아이즈원(IZ*ONE) - 비올레타(Violeta) 교차편집(stage mix)',
  'link_id': 'Qvd-ORcfook',
  'time': '3:25',
  'views': 712103},
 {'title': '청하 (CHUNG HA) - "벌써 12시 (Gotta Go)" Music Video',
  'link_id': 'HlN2BXNJzxA',
  'time': '3:42',
  'views': 27057777},
 {'title': "[PRODUCE 48] Nation's Hot Issue [국.슈 (국프의 핫이슈)] - Rumor [HAN|ROM|ENG Color Coded Lyrics]",
  'link_id': 'uTcZ3IizpLE',
  'time': '3:17',
  'views': 14855310},
 {'title': '[MV] OH MY GIRL(오마이걸) _ The fifth season(다섯 번째 계절) (SSFWL)',
  'link_id': 'udGwca1HBM4',
  'time': '4:01',
  'views': 18486892},
 {'title': '비올레타 (Violeta) - 아이즈원(IZ*ONE)  [뮤직뱅크 Music Bank] 20190405',
  'link_id': 'chPakGa0BwU',
  'time': '4:12',
  'views': 2225268},
 {'title': '[Full Album] IZ*ONE (아이즈원) - HEART*IZ (2nd Mini Album)',
  'link_id': 'Y4rpPrOOS_w',
  'time': '28:28',
  'views': 927046},
 {'title': "AB6IX (에이비식스) 'BREATHE' M/V",
  'link_id': 'RMJFEvHvmD0',
  'time': '3:41',
  'views': 4804841},
 {'title': "[ComeBack Stage] BLACKPINK - Don't Know What To Do,  블랙핑크 - Don't Know What To Do",
  'link_id': 'fNkxFo5Ef38',
  'time': '3:17',
  'views': 16534918},
 {'title': '[최초공개] 아이즈원(IZ*ONE) - 비올레타 (Violeta)｜IZ*ONE COMEBACK SHOW',
  'link_id': 'SDGWotu_pDY',
  'time': '3:27',
  'views': 5297383},
 {'title': '[M/V] PARK JI HOON(박지훈) - L.O.V.E',
  'link_id': 'Jk79mtC2xFY',
  'time': '4:49',
  'views': 1538482},
 {'title': 'ITZY "달라달라(DALLA DALLA)" M/V',
  'link_id': 'pNfTK39k55U',
  'time': '3:47',
  'views': 123182236},
 {'title': 'IZ*ONE - UP& Violeta I 아이즈원 - 하늘위로 & 비올레타 [Music Bank COME BACK/2019.04.05]',
  'link_id': 'nlxujPAwoXE',
  'time': '7:36',
  'views': 434445},
 {'title': "EXID(이엑스아이디) - 'ME&YOU' Music Video",
  'link_id': 'g9wfhJRyur8',
  'time': '3:25',
  'views': 9444591}]

# %%
len(list_dict)
# Out:
# 17

# %%
filtered_list = list(filter(lambda d: True if len(d['time'].split(':')) == 2 and int(d['time'].split(':')[0]) <= 5 else False, list_dict))

# %%
len(filtered_list)
# Out:
# 15

# %%
seconds =1559691056.728171
m, s = divmod(seconds, 60)
h, m = divmod(m, 60)
print("%d:%02d:%02d" % (h, m, s))
# Out:
# 433247:30:56
